# %%
import xml.etree.ElementTree as ET

data = '''
<person>
<name>Chuck</name>
<phone type="intl">
+1 734 303 4456
</phone>
<email hide="yes"/>
</person>'''

tree = ET.fromstring(data)
print('Name:', tree.find('name').text)
print('Attr:', tree.find('email').get('hide'))
# Out:
# Name: Chuck
# Attr: yes

# %%
#Looping through nodes
import xml.etree.ElementTree as ET

input = '''
<stuff>
<users>
<user x="2">
<id>001</id>
<name>Chuck</name>
</user>
<user x="7">
<id>009</id>
<name>Brent</name>
</user>
</users>
</stuff>'''

stuff = ET.fromstring(input)
lst = stuff.findall('users/user')
print('User count:', len(lst))


for item in lst:
    print('Name', item.find('name').text)
    print('Id', item.find('id').text)
    print('Attribute', item.get("x"))
# Out:
# User count: 2
# Name Chuck
# Id 001
# Attribute 2
# Name Brent
# Id 009
# Attribute 7

# %%
#JavaScript Object Notation - JSON
{
    "name": "Chuck",
    "phone":{
        "type":"intl",
        "number": "+1 734 303 4456"
    },
    "email": {
        "hide": "yes"
    }
}
# Out:
# {'email': {'hide': 'yes'},
#  'name': 'Chuck',
#  'phone': {'number': '+1 734 303 4456', 'type': 'intl'}}

# %%
#Parsing JSON
import json

# List of Dictionaries
input = '''
[
    {
        "id" : "001",
        "X"  : "2",
        "name" : "Chuck"    
    },
    {
        "id" : "009",
        "X"  : "7",
        "name" : "Chuck"    
    }

]'''

info = json.loads(input)
print("LOADS OUTPUT", info)    
print('User count:', len(info))
    
for item in info:
    print('Name', item['name'])
    print('Id', item['id'])
    print('Attribute', item['X'])
# Out:
# LOADS OUTPUT [{'id': '001', 'X': '2', 'name': 'Chuck'}, {'id': '009', 'X': '7', 'name': 'Chuck'}]
# User count: 2
# Name Chuck
# Id 001
# Attribute 2
# Name Chuck
# Id 009
# Attribute 7

# %%
#Google geocoding web service
import urllib.request, urllib.parse, urllib.error
import json

serviceurl = 'http://maps.googleapis.com/maps/api/geocode/json?'

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    url = serviceurl + urllib.parse.urlencode({'sensor': 'flase', 'address': address})

    print('Retrieving', url)
    uh = urllib.request.urlopen(url)
    data = uh.read().decode()
    print('retrieved', len(data), 'characters')
    
    try:
        js = json.loads(data)
    except:
        js = None
    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue
        
    print(json.dumps(js, indent=4))
    lat = js["results"][0]["geometry"]["location"]["lat"]
    lng = js["results"][0]["geometry"]["location"]["lng"]
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)
# Out:
# Enter location: sunnyvale
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=flase&address=sunnyvale
# retrieved 1743 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Sunnyvale",
#                     "short_name": "Sunnyvale",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Santa Clara County",
#                     "short_name": "Santa Clara County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "California",
#                     "short_name": "CA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Sunnyvale, CA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 37.4640869,
#                         "lng": -121.98267
#                     },
#                     "southwest": {
#                         "lat": 37.330236,
#                         "lng": -122.0655719
#                     }
#                 },
#                 "location": {
#                     "lat": 37.36883,
#                     "lng": -122.0363496
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.4640869,
#                         "lng": -121.98267
#                     },
#                     "southwest": {
#                         "lat": 37.330236,
#                         "lng": -122.0655719
#                     }
#                 }
#             },
#             "place_id": "ChIJO13QqUW2j4ARosN83Sb7jXY",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# lat 37.36883 lng -122.0363496
# Sunnyvale, CA, USA
# Enter location: done
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=flase&address=done
# retrieved 1902 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Dhone",
#                     "short_name": "Dhone",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Kurnool",
#                     "short_name": "Kurnool",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Andhra Pradesh",
#                     "short_name": "AP",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "India",
#                     "short_name": "IN",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "518222",
#                     "short_name": "518222",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Dhone, Andhra Pradesh 518222, India",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 15.4120458,
#                         "lng": 77.8818623
#                     },
#                     "southwest": {
#                         "lat": 15.3885757,
#                         "lng": 77.8618801
#                     }
#                 },
#                 "location": {
#                     "lat": 15.395984,
#                     "lng": 77.8727193
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 15.4120458,
#                         "lng": 77.8818623
#                     },
#                     "southwest": {
#                         "lat": 15.3885757,
#                         "lng": 77.8618801
#                     }
#                 }
#             },
#             "place_id": "ChIJBfrijBqBtjsRkvWb4k2bhyg",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# lat 15.395984 lng 77.8727193
# Dhone, Andhra Pradesh 518222, India
# Enter location:

# %%
#Security and API usage
#OAUTH
#An open protocol to allow secure authorization in a simple and standard method from web, mobile and desktop applications.
